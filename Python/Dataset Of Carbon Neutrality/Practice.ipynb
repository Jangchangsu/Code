# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
FIFA21 = pd.read_excel("C:\\Users\\jangh\\Desktop\\archive\\Career Mode player datasets - FIFA 15-21.xlsx", sheet_name = "FIFA 21")

# %%
FIFA21.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33 1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35 1985-02-05
# 2           J. Oblak                            Jan Oblak   27 1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31 1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28 1992-02-05
#
#    height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# ...

# %%
FIFA21.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
list(FIFA21.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club_name',
#  'league_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
# ...

# %%
FIFA21.drop(columns=['player_url','short_name','dob']).head()
# Out:
#    sofifa_id                            long_name  age  height_cm  weight_kg  \
# 0     158023       Lionel Andrés Messi Cuccittini   33        170         72
# 1      20801  Cristiano Ronaldo dos Santos Aveiro   35        187         83
# 2     200389                            Jan Oblak   27        188         87
# 3     188545                   Robert Lewandowski   31        184         80
# 4     190871        Neymar da Silva Santos Júnior   28        175         68
#
#   nationality            club_name             league_name  league_rank  \
# 0   Argentina         FC Barcelona  Spain Primera Division          1.0
# 1    Portugal             Juventus         Italian Serie A          1.0
# 2    Slovenia      Atlético Madrid  Spain Primera Division          1.0
# 3      Poland    FC Bayern München    German 1. Bundesliga          1.0
# 4      Brazil  Paris Saint-Germain          French Ligue 1          1.0
#
# ...

# %%
len(FIFA21)
# Out:
# 18944

# %%
FIFA21.query("overall < potential")
# Out:
#        sofifa_id                                         player_url  \
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 6         231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7         192448  https://sofifa.com/player/192448/marc-andre-te...
# 8         203376  https://sofifa.com/player/203376/virgil-van-di...
# 9         212831  https://sofifa.com/player/212831/alisson-ramse...
# ...          ...                                                ...
# 18938     257933  https://sofifa.com/player/257933/wenzhuo-huang...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
#
#            short_name              long_name  age        dob  height_cm  \
# 2            J. Oblak              Jan Oblak   27 1993-01-07        188
# ...

# %%
FIFA21.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 106, dtype: object

# %%
FIFA21.describe()
# Out:
#            sofifa_id           age                            dob  \
# count   18944.000000  18944.000000                          18944
# mean   226242.402872     25.225823  1994-10-18 19:44:17.432432384
# min        41.000000     16.000000            1967-02-26 00:00:00
# 25%    210030.500000     21.000000            1991-06-16 00:00:00
# 50%    232314.500000     25.000000            1995-03-30 00:00:00
# 75%    246760.250000     29.000000            1998-07-25 00:00:00
# max    258970.000000     53.000000            2003-09-27 00:00:00
# std     27171.091056      4.697354                            NaN
#
#           height_cm     weight_kg   league_rank       overall     potential  \
# count  18944.000000  18944.000000  18719.000000  18944.000000  18944.000000
# mean     181.190773     75.016892      1.357070     65.677787     71.086729
# min      155.000000     50.000000      1.000000     47.000000     47.000000
# ...
